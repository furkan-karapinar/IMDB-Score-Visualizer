# %%
import re
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By



def get_item(input_dizi_adi):
    def check_class_exists(item, class_name):
        try:
            item.find_element(By.CLASS_NAME, class_name)
            return True
        except NoSuchElementException:
            return False


    website_search_link = f"https://www.imdb.com/find/?q={input_dizi_adi}&ref_=nv_sr_sm"
    driver = webdriver.Chrome(executable_path="C:/Users/gardi/Desktop/chromedriver-win64/chromedriver.exe")
    wait_seconds = 5

    driver.get(website_search_link)
    driver.implicitly_wait(wait_seconds)

    elements = driver.find_elements(By.CLASS_NAME, 'ipc-metadata-list-summary-item__t')

    class_exists = check_class_exists(driver, 'ipc-metadata-list-summary-item__t')
    if not class_exists:
        print(f"/nDizi yok kardeşim/n")
        driver.quit()
        exit()

    text_list_search = [element.get_attribute('href') for element in elements]

    link = text_list_search[0]
    link = link.replace("https://www.imdb.com/title/", "").replace("/?ref_=fn_al_tt_1", "")
    website_link = f"https://www.imdb.com/title/{link}/episodes/?"

    driver.get(website_link)
    driver.implicitly_wait(wait_seconds)

    # Dizi adını sayfadan al
    dizi_adi_element = driver.find_element(By.XPATH,'//*[@id="__next"]/main/div/section/section/div[3]/section/section/div[2]/hgroup/h2')
    dizi_adi = dizi_adi_element.text
    print(f"Dizi Adı: {dizi_adi}")

    def get_results(page_count):
        items = driver.find_elements(By.CLASS_NAME, 'episode-item-wrapper')

        season_data = []
    
        for item in items:
            title_texts = []
            rating_texts = []

            title = item.find_elements(By.CLASS_NAME, 'ipc-title__text')
            class_exists = check_class_exists(item, 'ipc-rating-star--rating')

            if not class_exists:
                print(f"/n{page_count}. Sezon bölümleri puanlanmamış\n")
                return season_data

            rating = item.find_elements(By.CLASS_NAME, 'ipc-rating-star--rating')
            for title_ in title:
                a = str(title_.text).split(' ∙ ')[0]
                b = str(a).split('.')[-1]
                title_texts.append(b)

            for title_ in rating:
              rating_texts.append(title_.text)

            for rating_text, title_text in zip(rating_texts, title_texts):
             season_data.append({"Dizi Adı": dizi_adi, "Sezon": page_count, "Bölüm": title_text, "Puan": rating_text})
    
        return season_data

    elements = driver.find_elements(By.CSS_SELECTOR, '.ipc-tab.ipc-tab-link.ipc-tab--on-base')
    text_list = [element.text for element in elements]
    total_results_count = int(text_list[-1])

    all_season_data = []

    for i in range(1, total_results_count + 1):
        driver.get(f"{website_link}season={i}")
        driver.implicitly_wait(wait_seconds)
        season_data = get_results(i)
        all_season_data.extend(season_data)
        
      

    driver.get(f"https://www.imdb.com/title/{link}")
    driver.implicitly_wait(wait_seconds)

    img_element = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[1]/div[1]/div/div[1]/img')

    img_link = img_element.get_attribute('src')
    print(f"Resim Linki: {img_link}")
    driver.quit()
    
    return [all_season_data, img_link]
# Out:
# Dizi Adı: The Boys
#
# 5. Sezon bölümleri puanlanmamış
#
#     Dizi Adı  Sezon Bölüm Puan  \
# 0   The Boys      1    E1  8.7
# 1   The Boys      1    E2  8.5
# 2   The Boys      1    E3  8.3
# 3   The Boys      1    E4  8.7
# 4   The Boys      1    E5  8.3
# 5   The Boys      1    E6  8.1
# 6   The Boys      1    E7  8.7
# 7   The Boys      1    E8  9.1
# 8   The Boys      2    E1  8.1
# 9   The Boys      2    E2  7.7
# 10  The Boys      2    E3  9.0
# 11  The Boys      2    E4  8.0
# 12  The Boys      2    E5  8.3
# 13  The Boys      2    E6  8.9
# 14  The Boys      2    E7  9.0
# 15  The Boys      2    E8  9.4
# 16  The Boys      3    E1  8.3
# 17  The Boys      3    E2  8.6
# 18  The Boys      3    E3  8.2
# 19  The Boys      3    E4  8.9
# 20  The Boys      3    E5  8.3
# 21  The Boys      3    E6  9.6
# 22  The Boys      3    E7  8.8
# 23  The Boys      3    E8  8.2
# 24  The Boys      4    E1  7.4
# 25  The Boys      4    E2  7.1
# 26  The Boys      4    E3  7.5
# 27  The Boys      4    E4  8.9
# 28  The Boys      4    E5  8.1
# 29  The Boys      4    E6  7.5
# 30  The Boys      4    E7  8.3
# 31  The Boys      4    E8  9.1
#
#                                            Image Link
# 0   https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 1   https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 2   https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 3   https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 4   https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 5   https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 6   https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 7   https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 8   https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 9   https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 10  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 11  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 12  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 13  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 14  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 15  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 16  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 17  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 18  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 19  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 20  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 21  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 22  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 23  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 24  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 25  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 26  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 27  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 28  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 29  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 30  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
# 31  https://m.media-amazon.com/images/M/MV5BYTY2Zj...
